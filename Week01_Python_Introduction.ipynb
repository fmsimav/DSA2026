# %% [markdown]
# # Python’a Giriş & Programlama Temelleri
#
# ## 1. Hafta
#
# Bu notebook, Python ile Data Structures & Algorithms dersinin **1. haftası** için hazırlanmıştır.

# %% [markdown]
# ## Python Nedir?
# - Yüksek seviyeli
# - Okunabilir syntax
# - Geniş kullanım alanı (Data, Web, Otomasyon)

# %%
print("Hello, World!")

# %% [markdown]
# ## Değişkenler ve Veri Tipleri

# %%
age = 20
name = "Ali"
height = 1.75
is_student = True

print(age, name, height, is_student)

# %% [markdown]
# ## type() Fonksiyonu

# %%
print(type(age))
print(type(name))
print(type(height))
print(type(is_student))

# %% [markdown]
# ## input() ile Kullanıcıdan Veri Alma

# %%
name = input("Adınızı giriniz: ")
print("Merhaba", name)

# %% [markdown]
# ## Tip Dönüşümü

# %%
age = input("Yaşınızı giriniz: ")
age = int(age)
print("5 yıl sonra:", age + 5)

# %% [markdown]
# ## Mini Uygulama – Basit Hesap Makinesi

# %%
a = int(input("Birinci sayı: "))
b = int(input("İkinci sayı: "))

print("Toplam:", a + b)
print("Fark:", a - b)
print("Çarpım:", a * b)
print("Bölüm:", a / b)

# %% [markdown]
# ## Haftalık Ödev
# 1. Dikdörtgen alan ve çevre hesaplayan program yazınız.
# 2. Doğum yılına göre yaş hesaplayan program yazınız.
